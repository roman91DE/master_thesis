# %%
# !conda info
# !printf "Current Directory=$(pwd)"
# Out:
#      active environment : dataScience
#     active env location : /Users/rmn/miniconda3/envs/dataScience
#             shell level : 4
#        user config file : /Users/rmn/.condarc
#  populated config files :
#           conda version : 22.11.1
#     conda-build version : not installed
#          python version : 3.9.15.final.0
#        virtual packages : __archspec=1=arm64
#                           __osx=13.0.1=0
#                           __unix=0=0
#        base environment : /Users/rmn/miniconda3  (writable)
#       conda av data dir : /Users/rmn/miniconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-arm64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-arm64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /Users/rmn/miniconda3/pkgs
#                           /Users/rmn/.conda/pkgs
#        envs directories : /Users/rmn/miniconda3/envs
#                           /Users/rmn/.conda/envs
#                platform : osx-arm64
#              user-agent : conda/22.11.1 requests/2.28.1 CPython/3.9.15 Darwin/22.1.0 OSX/13.0.1
#                 UID:GID : 501:20
#              netrc file : None
#            offline mode : False
#
# Current Directory=/Users/rmn/masterThesis/eda-gp-2020/experiments/airfoil_ptdaegp-daegp_rwsr_1hl

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from statistics import mean
from math import sqrt
from scipy.stats import mannwhitneyu
from typing import Tuple

# %%
# %matplotlib inline

# %%
# path to csv results
AIRFOIL_PATH = "./results.csv"
IMG_PATH="/Users/rmn/masterThesis/master_thesis/img/airfoil_exploratory"

# %%
def df_from_path(path: str) -> pd.DataFrame:
    return pd.read_csv(
        filepath_or_buffer=path,
        sep="?",
    )

# %%
# %%bash
# # check if csv contains same number of rows for both algorithms
#
# printf "Pre-trained DAE-LSTM Cases:" ; cat ./results.csv | grep ^pt  | wc -l
# printf "Regular DAE-LSTM Cases    :" ; cat ./results.csv | grep ^dae | wc -l
#
# # 10 runs * 20 generations (0-20) = 210
# Out:
# Pre-trained DAE-LSTM Cases:     210
# Regular DAE-LSTM Cases    :     210

# %%
RUNS=10
GENERATIONS=20
HIDDENLAYERS=1

# %%
AIRFOIL_RESULTS = df_from_path(AIRFOIL_PATH)
AIRFOIL_RESULTS.describe()
# Out:
#           test_no  generation  after_selection_depth_25percentile  \
# count  420.000000  420.000000                          420.000000
# mean     4.500000   10.000000                            2.758929
# std      2.875707    6.062522                            1.252352
# min      0.000000    0.000000                            1.000000
# 25%      2.000000    5.000000                            2.000000
# 50%      4.500000   10.000000                            2.000000
# 75%      7.000000   15.000000                            3.000000
# max      9.000000   20.000000                            7.000000
#
#        after_selection_depth_50percentile  after_selection_depth_75percentile  \
# count                          420.000000                          420.000000
# mean                             3.348810                            4.097024
# std                              1.360147                            1.397862
# min                              1.000000                            2.000000
# 25%                              2.000000                            3.000000
# 50%                              3.000000                            4.000000
# 75%                              4.000000                            5.000000
# max                              7.000000                            8.000000
#
#        after_selection_depth_avg  \
# count                 420.000000
# mean                    3.524314
# std                     1.222052
# min                     1.456000
# 25%                     2.605000
# 50%                     3.312000
# 75%                     4.116500
# max                     7.238000
#
#        after_selection_depth_avg_lev_distance_denoising  \
# count                                        420.000000
# mean                                           0.453195
# std                                            0.190410
# min                                            0.000000
# 25%                                            0.348000
# 50%                                            0.437000
# 75%                                            0.550500
# max                                            1.098000
#
#        after_selection_depth_avg_norm_lev_distance_denoising  \
# count                                         420.000000
# mean                                            0.044943
# std                                             0.010566
# min                                             0.000000
# 25%                                             0.045000
# 50%                                             0.047000
# 75%                                             0.049000
# max                                             0.057000
#
#        after_selection_depth_avg_size  \
# count                      420.000000
# mean                         9.381133
# std                          5.705296
# min                          3.772000
# 25%                          6.099000
# 50%                          7.954000
# 75%                         10.326000
# max                         33.720000
#
#        after_selection_depth_avg_size_corr_minus_orig  ...  size_unique_rate  \
# count                                      420.000000  ...        420.000000
# mean                                        -0.000719  ...          0.551705
# std                                          0.023958  ...          0.271792
# min                                         -0.080000  ...          0.014000
# 25%                                         -0.016000  ...          0.341000
# 50%                                          0.000000  ...          0.541000
# 75%                                          0.014000  ...          0.762000
# max                                          0.086000  ...          1.000000
#
#        std_norm_lev_distance_denoising  std_size_corr_minus_orig    time_used  \
# count                       420.000000                420.000000   420.000000
# mean                          0.069290                  0.535133  1976.087255
# std                           0.019541                  0.154360   948.012795
# min                           0.000000                  0.000000    13.309439
# 25%                           0.062750                  0.487750  1367.622499
# 50%                           0.071000                  0.547500  1823.574087
# 75%                           0.080000                  0.612250  2612.371143
# max                           0.110000                  0.906000  4711.395426
#
#        tourn_size      unique  unique_output_vector_rate  \
# count       420.0  420.000000                 420.000000
# mean          7.0  275.852381                   0.376229
# std           0.0  135.895780                   0.274544
# min           7.0    7.000000                   0.014000
# 25%           7.0  170.500000                   0.173500
# 50%           7.0  270.500000                   0.275000
# 75%           7.0  381.000000                   0.513500
# max           7.0  500.000000                   0.988000
#
#        unique_output_vector_rate_int  unique_output_vector_rate_test  \
# count                     420.000000                      420.000000
# mean                        0.272876                        0.376233
# std                         0.203117                        0.274548
# min                         0.014000                        0.014000
# 25%                         0.124000                        0.173500
# 50%                         0.190000                        0.275000
# 75%                         0.372500                        0.513500
# max                         0.804000                        0.988000
#
#        unique_rate
# count   420.000000
# mean      0.551705
# std       0.271792
# min       0.014000
# 25%       0.341000
# 50%       0.541000
# 75%       0.762000
# max       1.000000
#
# [8 rows x 473 columns]

# %%
def split_df(df: pd.DataFrame, dir1: str, dir2: str) -> Tuple[pd.DataFrame, pd.DataFrame]:
    return df.query("directory == @dir1").copy(), df.query("directory == @dir2").copy()

# %%
pt_results, reg_results = split_df(AIRFOIL_RESULTS, "pt_dae_gp", "dae_gp")
assert pt_results.shape == reg_results.shape
NROWS, NCOLS = pt_results.shape

# %%
pt_results.head()
# Out:
#    directory rund_id  test_no  generation  after_selection_depth_25percentile  \
# 0  pt_dae_gp  1_6160        1           0                                 2.0
# 1  pt_dae_gp  1_6160        1           1                                 2.0
# 2  pt_dae_gp  1_6160        1           2                                 2.0
# 3  pt_dae_gp  1_6160        1           3                                 2.0
# 4  pt_dae_gp  1_6160        1           4                                 2.0
#
#    after_selection_depth_50percentile  after_selection_depth_75percentile  \
# 0                                 3.5                                 5.0
# 1                                 3.0                                 4.0
# 2                                 2.0                                 3.0
# 3                                 2.0                                 4.0
# 4                                 2.0                                 4.0
#
#   after_selection_depth_algorithm  after_selection_depth_avg  \
# 0                        DAE_LSTM                      3.688
# 1                        DAE_LSTM                      3.188
# 2                        DAE_LSTM                      3.042
# 3                        DAE_LSTM                      3.066
# 4                        DAE_LSTM                      3.224
#
#    after_selection_depth_avg_lev_distance_denoising  ...  trainableParams  \
# 0                                             0.000  ...             None
# 1                                             0.944  ...           177231
# 2                                             0.624  ...           177231
# 3                                             0.620  ...           177231
# 4                                             0.552  ...           177231
#
#    training_error   training_mode unique  unique_output_vector_rate  \
# 0            None  early_stopping    500                      0.988
# 1            0.01  early_stopping    500                      0.932
# 2           0.002  early_stopping    484                      0.896
# 3           0.003  early_stopping    471                      0.886
# 4           0.002  early_stopping    454                      0.834
#
#    unique_output_vector_rate_int  unique_output_vector_rate_sel  \
# 0                          0.800                           None
# 1                          0.696                          0.334
# 2                          0.642                          0.306
# 3                          0.636                          0.302
# 4                          0.588                          0.302
#
#   unique_output_vector_rate_test  unique_rate  \
# 0                          0.988        1.000
# 1                          0.932        1.000
# 2                          0.896        0.968
# 3                          0.886        0.942
# 4                          0.834        0.908
#
#    wass_norm_lev_div_sampled_vs_selected
# 0                                   None
# 1                                  0.017
# 2                                  0.013
# 3                                  0.034
# 4                                  0.034
#
# [5 rows x 771 columns]

# %%
reg_results.head()
# Out:
#     directory rund_id  test_no  generation  \
# 210    dae_gp  1_9930        1           0
# 211    dae_gp  1_9930        1           1
# 212    dae_gp  1_9930        1           2
# 213    dae_gp  1_9930        1           3
# 214    dae_gp  1_9930        1           4
#
#      after_selection_depth_25percentile  after_selection_depth_50percentile  \
# 210                                 2.0                                 3.0
# 211                                 2.0                                 3.0
# 212                                 2.0                                 3.0
# 213                                 2.0                                 2.0
# 214                                 2.0                                 2.0
#
#      after_selection_depth_75percentile after_selection_depth_algorithm  \
# 210                                 5.0                        DAE_LSTM
# 211                                 4.0                        DAE_LSTM
# 212                                 4.0                        DAE_LSTM
# 213                                 3.0                        DAE_LSTM
# 214                                 3.0                        DAE_LSTM
#
#      after_selection_depth_avg  \
# 210                      3.632
# 211                      3.158
# 212                      2.892
# 213                      2.584
# 214                      2.214
#
#      after_selection_depth_avg_lev_distance_denoising  ...  trainableParams  \
# 210                                             0.000  ...             None
# 211                                             0.706  ...           222861
# 212                                             0.474  ...            50340
# 213                                             0.422  ...            18930
# 214                                             0.338  ...             7523
#
#      training_error   training_mode unique  unique_output_vector_rate  \
# 210            None  early_stopping    500                      0.968
# 211           0.002  early_stopping    488                      0.904
# 212           0.016  early_stopping    420                      0.736
# 213           0.043  early_stopping    316                      0.512
# 214           0.056  early_stopping    270                      0.428
#
#      unique_output_vector_rate_int  unique_output_vector_rate_sel  \
# 210                          0.780                           None
# 211                          0.582                          0.304
# 212                          0.406                          0.298
# 213                          0.284                          0.224
# 214                          0.252                          0.158
#
#     unique_output_vector_rate_test  unique_rate  \
# 210                          0.968        1.000
# 211                          0.904        0.976
# 212                          0.736        0.840
# 213                          0.512        0.632
# 214                          0.428        0.540
#
#      wass_norm_lev_div_sampled_vs_selected
# 210                                   None
# 211                                  0.016
# 212                                  0.031
# 213                                  0.057
# 214                                  0.052
#
# [5 rows x 771 columns]

# %%
def filter_df_by_headers(df, headers):
    return df[df.columns.intersection(headers)]

# %%
AIRFOIL_RESULTS.columns
# Out:
# Index(['directory', 'rund_id', 'test_no', 'generation',
#        'after_selection_depth_25percentile',
#        'after_selection_depth_50percentile',
#        'after_selection_depth_75percentile', 'after_selection_depth_algorithm',
#        'after_selection_depth_avg',
#        'after_selection_depth_avg_lev_distance_denoising',
#        ...
#        'trainableParams', 'training_error', 'training_mode', 'unique',
#        'unique_output_vector_rate', 'unique_output_vector_rate_int',
#        'unique_output_vector_rate_sel', 'unique_output_vector_rate_test',
#        'unique_rate', 'wass_norm_lev_div_sampled_vs_selected'],
#       dtype='object', length=771)

# %%
def mean_vals_per_gen(df: pd.DataFrame, val, ignoreGen0: bool=False):
    
    mean_vals = []
    
    gens = range(min(df["generation"]), max(df["generation"]))
    for gen in gens:

            if ignoreGen0 and gen == 0:
                continue
        
            gen_df = df.loc[df['generation'] == gen]
    
            test_nums = range(min(df["test_no"]), max(df["test_no"]))
            vals = []
            for test_num in test_nums:
                
                row = gen_df.loc[gen_df["test_no"] == test_num]
                vals.append(float(row[val].iloc[0]))


            mean_vals.append(mean(vals))
    
    return mean_vals    

def vals_per_test_num(df: pd.DataFrame, val, test_num, ignoreGen0: bool=False):
    
    vals = []
    
    gens = range(min(df["generation"]), max(df["generation"]))
    for gen in gens:

            if ignoreGen0 and gen == 0:
                continue
        
            gen_df = df.loc[df['generation'] == gen]
    
                
            row = gen_df.loc[gen_df["test_no"] == test_num]
            vals.append(float(row[val].iloc[0]))
    
    return vals    



def root_mean_vals_per_gen(df: pd.DataFrame, val):
    
    mean_vals = []
    
    gens = range(min(df["generation"]), max(df["generation"]))
    for gen in gens:
        
            gen_df = df.loc[df['generation'] == gen]
    
            test_nums = range(min(df["test_no"]), max(df["test_no"]))
            vals = []
            for test_num in test_nums:
                
                row = gen_df.loc[gen_df["test_no"] == test_num]
                vals.append(row[val].iloc[0])

            mean_vals.append(sqrt(mean(vals)))
    
    return mean_vals

# %%
vals_per_gen(pt_results, "fitness_train",0, ignoreGen0=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/dataScience/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/miniconda3/envs/dataScience/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/dataScience/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fitness_train'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 vals_per_gen(pt_results, "fitness_train",0, ignoreGen0=True)
#
# Cell In [26], line 39, in vals_per_gen(df, val, test_num, ignoreGen0)
#      35         gen_df = df.loc[df['generation'] == gen]
#      38         row = gen_df.loc[gen_df["test_no"] == test_num]
# ---> 39         vals.append(float(row[val].iloc[0]))
#      41 return vals
#
# File ~/miniconda3/envs/dataScience/lib/python3.10/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/miniconda3/envs/dataScience/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'fitness_train'

# %%
# rmse
reg_mean_best_fit = root_mean_vals_per_gen(reg_results, "best_fitness")
pt_mean_best_fit =  root_mean_vals_per_gen(pt_results, "best_fitness")
reg_mean_best_fit_test = root_mean_vals_per_gen(reg_results, "best_fitness_test")
pt_mean_best_fit_test =  root_mean_vals_per_gen(pt_results, "best_fitness_test")
gens = list(range(len(reg_mean_best_fit)))

fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(gens, reg_mean_best_fit, "b" , label="DAE-LSTM (Training)")
ax.plot(gens, reg_mean_best_fit_test, "b" ,linestyle="dotted", label="DAE-LSTM (Testing)")

ax.plot(gens, pt_mean_best_fit, "g" , label="Pre-Trained-DAE-LSTM (Training)")
ax.plot(gens, pt_mean_best_fit_test, "g" ,linestyle="dotted", label="Pre-Trained-DAE-LSTM (Testing)")

ax.grid(True)


ax.set_xlabel("generations")
ax.set_ylabel("RMSE")

ax.legend()

ax.set_title("Best Fitness per Generation")
plt.savefig(f"{IMG_PATH}/best_fitness_per_generation_rmse.png")
plt.show()




mannwhitneyu(reg_mean_best_fit, pt_mean_best_fit)
# Out:
# MannwhitneyuResult(statistic=120.0, pvalue=0.03151710207456157)

# %%
# plot number of evaluations per generation

reg_mean_nevals = mean_vals_per_gen(reg_results, "nevals")
pt_mean_nevals =  mean_vals_per_gen(pt_results, "nevals")
gens = list(range(len(reg_mean_nevals)))

fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(gens, reg_mean_nevals, "b" , label="DAE-LSTM")
ax.plot(gens, pt_mean_nevals, "g" , label="Pre-Trained-DAE-LSTM")
ax.grid(True)


ax.set_xlabel("generations")
ax.set_ylabel("Total Number of Fitness Evaluations")

ax.legend()

ax.set_title("Number of Fitness Evaluations")


plt.show()
plt.savefig("fitness_evals_per_generation.png")
mannwhitneyu(reg_mean_nevals, pt_mean_nevals)
# Out:
# MannwhitneyuResult(statistic=210.5, pvalue=0.786765171721284)

# %%
# plot unique rate per generation

reg_mean_unique_rate = mean_vals_per_gen(reg_results, "unique_rate")
pt_mean_unique_rate =  mean_vals_per_gen(pt_results, "unique_rate")
gens = list(range(len(reg_mean_nevals)))

fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(gens, reg_mean_unique_rate, "b" , label="DAE-LSTM")
ax.plot(gens, pt_mean_unique_rate, "g" , label="Pre-Trained-DAE-LSTM")
ax.grid(True)


ax.set_xlabel("generations")
ax.set_ylabel("Unique Rate")

ax.legend()

ax.set_title("Unique Rate per Generation")


plt.show()
plt.savefig("unique_rate_by_generation.png")

mannwhitneyu(reg_mean_unique_rate, pt_mean_unique_rate)
# Out:
# MannwhitneyuResult(statistic=279.5, pvalue=0.03259333353309787)

# %%
# plot avg size

reg_mean_size = mean_vals_per_gen(reg_results, "avg_size")
pt_mean_size =  mean_vals_per_gen(pt_results, "avg_size")
gens = list(range(len(reg_mean_size)))

fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(gens, reg_mean_size, "b" , label="DAE-LSTM")
ax.plot(gens, pt_mean_size, "g" , label="Pre-Trained-DAE-LSTM")
ax.grid(True)


ax.set_xlabel("generations")
ax.set_ylabel("Tree Size")

ax.legend()

ax.set_title("Average Tree Size per Generation")


plt.show()
plt.savefig("avg_size_per_generation.png")
mannwhitneyu(reg_mean_size, pt_mean_size)
# Out:
# MannwhitneyuResult(statistic=96.0, pvalue=0.005115262023126529)

# %%
fig, ((ul,ur),(ll,lr)) = plt.subplots(nrows=2, ncols=2)
fig.set_figwidth(12,12)

# ul - fitness

reg_mean_best_fit = root_mean_vals_per_gen(reg_results, "best_fitness")
pt_mean_best_fit =  root_mean_vals_per_gen(pt_results, "best_fitness")
reg_mean_best_fit_test = root_mean_vals_per_gen(reg_results, "best_fitness_test")
pt_mean_best_fit_test =  root_mean_vals_per_gen(pt_results, "best_fitness_test")
gens = list(range(len(reg_mean_best_fit)))

ul.plot(gens, reg_mean_best_fit, "b" , label="DAE-GP(Training)")
ul.plot(gens, reg_mean_best_fit_test, "b" ,linestyle="dotted", label="DAE-GP(Testing)")

ul.plot(gens, pt_mean_best_fit, "g" , label="Pre-Trained(Training)")
ul.plot(gens, pt_mean_best_fit_test, "g" ,linestyle="dotted", label="Pre-Trained(Testing)")

ul.grid(True)


ul.set_xlabel("generations")
ul.set_ylabel("RMSE")
ul.set_title("Best Fitness")


# ur - fitness evals

reg_mean_nevals = mean_vals_per_gen(reg_results, "nevals")
pt_mean_nevals =  mean_vals_per_gen(pt_results, "nevals")

ur.plot(gens, reg_mean_nevals, "b" , label="_DAE-LSTM")
ur.plot(gens, pt_mean_nevals, "g" , label="_Pre-Trained-DAE-LSTM")
ur.grid(True)


ur.set_xlabel("generations")
ur.set_ylabel("Fitness Evaluations")

ur.set_title("Number of Fitness Evaluations")

# ll - size

reg_mean_size = mean_vals_per_gen(reg_results, "avg_size")
pt_mean_size =  mean_vals_per_gen(pt_results, "avg_size")

ll.plot(gens, reg_mean_size, "b" , label="_DAE-LSTM")
ll.plot(gens, pt_mean_size, "g" , label="_Pre-Trained-DAE-LSTM")
ll.grid(True)


ll.set_xlabel("generations")
ll.set_ylabel("Tree Size")

ll.set_title("Average Tree Size")


# lr - unique rate

reg_mean_unique_rate = mean_vals_per_gen(reg_results, "unique_rate")
pt_mean_unique_rate =  mean_vals_per_gen(pt_results, "unique_rate")

lr.plot(gens, reg_mean_unique_rate, "b" , label="_DAE-LSTM")
lr.plot(gens, pt_mean_unique_rate, "g" , label="_Pre-Trained-DAE-LSTM")
lr.grid(True)


lr.set_xlabel("generations")
lr.set_ylabel("Unique Rate")


lr.set_title("Unique Rate per Generation")
fig.legend()
fig.set_tight_layout(True)
fig.suptitle("DAE-GP - Airfoil - Results")
fig.set_size_inches(12,10)
